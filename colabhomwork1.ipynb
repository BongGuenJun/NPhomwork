# %%
#202004443 전봉근

a=1
b=2
print(a+b)
print(a,b)

# %%
a = (input("숫자를 입력하시오 : "))

if a.isdecimal()==True:

    if int(a) < 30:
      for i in range(1,int(a)+1):
        for j in range(1,i+1):
            print(j,end="")
        print()
       

    else:
       print("숫자가 너무 많습니다")


else: 
  print("정수로 입력하세요")
# Out:
# 숫자를 입력하시오 : 정수
# 정수로 입력하세요
