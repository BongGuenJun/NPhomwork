# %% [markdown]
# <a href="https://colab.research.google.com/github/BongGuenJun/Python/blob/main-branch/Gradient_descent%2C_matplotlib%2C_seaborn_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0,3)
y=x**2+np.sin(3*x+7)
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

def f(a,b):
	return a**2 + (1/2)* b**4 +2* np.sin(a*b)

def grad_f(a,b):
  h=1e-5
  return [(f(a+h,b) - f(a-h,b))/(2*h),(f(a,b+h) - f(a,b-h))/(2*h)]

def gradient_descent(theta0, iters, alpha):
	history = [theta0] 
	theta = theta0     
	for i in range(iters):
		gradient = grad_f(theta[0],theta[1])
		theta = [a - alpha*b for a,b in zip(theta, gradient)]
		history.append(theta)
	return history

history = gradient_descent(theta0 = [-2, -2], iters =30, alpha = 0.02)

fig = plt.figure(figsize=(20, 15))
ax = fig.gca(projection='3d')
a = np.arange(-2, 2, 0.25)
b = np.arange(-2, 2, 0.25)
a, b = np.meshgrid(a, b)
c = f(a,b)
surf = ax.plot_surface(a, b, c, rstride=1, cstride=1, alpha=0.3, 
		 linewidth=0, antialiased=False, cmap='rainbow')

a = np.array([x[0] for x in history])
b = np.array([x[1] for x in history])
c =  f(a,b)
ax.scatter(a, b, c, color="r"); 

print(c)

plt.xlabel('Feature A')
plt.ylabel('Feature B')


plt.show()
# Out:
# [10.48639501  7.84935872  7.13087209  6.80431389  6.61014033  6.46837728
#   6.34679839  6.22969298  6.10792708  5.97518621  5.82642772  5.65728629
#   5.46399062  5.24361731  4.99457427  4.71717827  4.41412865  4.09064719
#   3.75411706  3.41322567  3.07682232  2.75281883  2.44741768  2.16478953
#   1.9071499   1.67508844  1.46799551  1.28447418  1.12267987  0.98057157
#   0.85608201]

# %%
from google.colab import files
myfile = files.upload()
# Out:
#      <input type="file" id="files-77125391-3f0f-4a53-ae05-f60094c21a3f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-77125391-3f0f-4a53-ae05-f60094c21a3f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
import pandas as pd
import seaborn as sns
CData = pd.read_csv(io.BytesIO(myfile['caffeinetest.csv']))
print(CData.shape)
print(CData.head())
CData.tail()
# Out:
# (610, 5)
#                          drink  Volume (ml)  Calories  Caffeine (mg)    type
# 0                 Costa Coffee   256.993715         0            277  Coffee
# 1  Coffee Friend Brewed Coffee   250.191810         0            145  Coffee
# 2           Hell Energy Coffee   250.191810       150            100  Coffee
# 3           Killer Coffee (AU)   250.191810         0            430  Coffee
# 4                 Nescafe Gold   250.191810         0             66  Coffee
#                          drink  Volume (ml)  Calories  Caffeine (mg)   type
# 605   Pep Talk Sparkling Water      354.882         0             55  Water
# 606        Polar Seltzer Water      354.882         0              0  Water
# 607     Yerbae Sparkling Water      354.882         0            100  Water
# 608                Tonic Water      295.735       110              0  Water
# 609  MiO Energy Water Enhancer      236.588         0             60  Water

# %%
sns.set_theme()
sns.set(rc={"figure.dpi":300})
sns.set(rc={"figure.figsize":(6,3)})

sns.scatterplot(x="drink", y="Calories", data=CData, hue="Caffeine (mg)")

# %%
sns.histplot( y="drink",data =CData)

# %%
sns.histplot(x="Calories", data = CData)

# %%
sns.histplot(x="Calories", data = CData, kde ="True")

# %%
sns.histplot(x="Calories", data=CData, hue = "type")

# %%
sns.barplot(x="Calories", y="Caffeine (mg)", data =irisData)

# %%
sns.boxplot(x="Calories", y="Caffeine (mg)", data=irisData)
